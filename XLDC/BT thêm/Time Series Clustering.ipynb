# %%
import numpy as np
import pandas as pd

# %%
i = 1
data = pd.read_csv(str(i)+'.txt')

# %%
data
# Out:
#       22 49 35
# 0     22 49 35
# 1     22 52 35
# 2     22 52 35
# 3     21 52 34
# 4     22 51 34
# ...        ...
# 2161  23 41 44
# 2162  23 42 44
# 2163  23 42 44
# 2164  22 40 43
# 2165  20 44 46
#
# [2166 rows x 1 columns]

# %%
t = open ( '1.txt' , 'r')
l = []
l = [ line.split() for line in t]
o = np.array(l)
print(o)
# Out:
# [['22' '49' '35']
#  ['22' '49' '35']
#  ['22' '52' '35']
#  ...
#  ['23' '42' '44']
#  ['22' '40' '43']
#  ['20' '44' '46']]

# %%
a = []
for i in range(1,980):
  a.append(str(i)+'.txt')

c = []
d = []
for i in a:
  t = open(i,'r')
  c = [line.split() for line in t]
  if c == '\n\n'
  d.append(c)
# Out:
#   File "<ipython-input-46-4843a13d11fe>", line 10
#     if c == '\n\n'
#                   ^
# SyntaxError: invalid syntax

# %%
c = np.array(c)

# %%
c.shape
# Out:
# (1050, 3)

# %%
c[1]
# Out:
# array(['39', '31', '52'], dtype='<U2')

# %%
d = np.array(d)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   """Entry point for launching an IPython kernel.

# %%
d.shape
# Out:
# (979,)

# %%
x = 0

# %%
for i in range(0,10):
  x+str(i) = i
# Out:
#   File "<ipython-input-52-b1d4cb0817b2>", line 2
#     x+str(i) = i
#     ^
# SyntaxError: can't assign to operator
