# %% [markdown]
# # Lab04B_Câu 3

# %%
# import basic libraries 
import numpy as np 
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
# import plot libraries 
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
# Read data
data = pd.read_csv("telecom_churn.csv")
data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
data.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
def DrawBoxplot2(DataFrame, xAtt, yAtt, hAtt="N/A"):
  import matplotlib.pyplot as plt
  import seaborn as sns
  plt.figure()
  plt.subplots(figsize=(10,5))
  if(hAtt == "N/A"):
    sns.boxplot(x=xAtt, y=yAtt,  data=DataFrame)
  else:
    sns.boxplot(x=xAtt, y=yAtt,  hue=hAtt,  data=DataFrame)
  plt.show()

# %%
DrawBoxplot2(data, xAtt = 'Churn', yAtt='Total day minutes', hAtt = 'International plan')

# %% [markdown]
# ## Access:
#
# $\textit{Từ biểu đồ 1}$,
# + Có thể thấy giá trị Q1, Q2, Q3 của thuộc tính 'Churn' có giá trị 'True' luôn lớn hơn so với thuộc tính 'Churn' có giá trị 'False' khi xét trong thuộc tính 'International plan'.
# + Và các Outlier, của thuộc tính 'Churn' có giá trị 'True' thì nhỏ hơn so với thuộc tính 'Churn' có giá trị 'False' khi xét trong thuộc tính 'International plan'.
#
# $\textit{Tuy nhiên, trong biểu đồ 2,}$
# + Có thể thấy giá trị Q1, Q2, Q3 của thuộc tính 'Churn' có giá trị 'False' luôn lớn hơn so với thuộc tính 'Churn' có giá trị 'True' khi xét trong thuộc tính 'International plan'.
# + Và các Outlier, của thuộc tính 'Churn' có giá trị 'False' thì lớn hơn so với thuộc tính 'Churn' có giá trị 'True' khi xét trong thuộc tính 'International plan'.
#
# $\rightarrow$Qua đó cho thấy sự biến thiên dữ liệu khá lớn ở thuộc tính 'Churn' có giá trị 'False'.

# %%
DrawBoxplot2(data, xAtt = 'Churn', yAtt='Total day minutes', hAtt = 'Voice mail plan')

# %% [markdown]
# ## Access:
#
# $\textit{Từ biểu đồ 1}$,
# + Có thể thấy giá trị Q1, Q2, Q3 của thuộc tính 'Churn' có giá trị 'False' luôn lớn hơn so với thuộc tính 'Churn' có giá trị 'True' khi xét trong thuộc tính 'International plan'.
# + Và các Outlier, của thuộc tính 'Churn' có giá trị 'False' thì lớn hơn so với thuộc tính 'Churn' có giá trị 'True' khi xét trong thuộc tính 'International plan'.
#
# $\textit{Tuy nhiên, trong biểu đồ 2}$
# + Có thể thấy giá trị Q1, Q2, Q3 của thuộc tính 'Churn' có giá trị 'False' luôn nhỏ hơn so với thuộc tính 'Churn' có giá trị 'True' khi xét trong thuộc tính 'International plan'.
# + Và các Outlier, của thuộc tính 'Churn' có giá trị 'False' thì nhỏ hơn so với thuộc tính 'Churn' có giá trị 'True' khi xét trong thuộc tính 'International plan'.
#
# $\rightarrow$Qua đó cho thấy sự biến thiên dữ liệu khá lớn ở thuộc tính 'Churn' có giá trị 'True'.

# %%
def DrawCountplot(DataFrame, att, hatt="N/A"):
  import matplotlib.pyplot as plt
  import seaborn as sns
  if(hatt == "N/A"):
    sns.countplot(x=att, data=DataFrame)
  else:
    sns.countplot(x=att, hue=hatt, data=DataFrame)
  plt.show()

# %%
data['Area code'].value_counts()
# Out:
# 415    1655
# 510     840
# 408     838
# Name: Area code, dtype: int64

# %%
DrawCountplot(data, 'Area code', 'Churn')

# %% [markdown]
# ## Access:
# - Mã vùng được chia thành 3 loại chính: 408, 415, 510.
# - Đa số khách hàng thuộc mã vùng 415, đạt số lượng là 1655.
# - Số lượng khách hàng thấp nhất nằm ở mã vùng 408, với 838 khách hàng.

# %%
data['Customer service calls'].value_counts()
# Out:
# 1    1181
# 2     759
# 0     697
# 3     429
# 4     166
# 5      66
# 6      22
# 7       9
# 8       2
# 9       2
# Name: Customer service calls, dtype: int64

# %%
DrawCountplot(data, 'Customer service calls', 'Churn')

# %% [markdown]
# ## Access:
#
# - Các cuộc gọi dịch vụ tập trung chủ yếu ở 1, 2, 3 cuộc gọi.
# - Số lượng khách hàng chỉ sử dụng cuộc gọi dịch vụ 1 lần là nhiều nhất, với 1181 khách hàng.
# - Chỉ có 2 khách hàng sử dụng cuộc gọi dịch vụ đến 9 lần.

# %%
def DrawJointPlot(DataFrame, XAtt, yAtt, bins = 20):
  import seaborn as sns
  import matplotlib.pyplot as plt
  from scipy import stats
  sns.set(color_codes=True)
  sns.distplot(data[XAtt], bins=bins);

  df = pd.DataFrame(DataFrame, columns=[XAtt,yAtt])
  df = df.reset_index(drop=True)
  sns.jointplot(x=XAtt, y=yAtt, data=df);

# %% [markdown]
# # Tách dữ liệu theo thuộc tính Churn là 'False'

# %%
dataNChurn = data[data['Churn'] == False]
dataNChurn.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
DrawJointPlot(dataNChurn, 'Total day minutes', 'Total day calls')

# %% [markdown]
# ## Access:
# - Khách hàng sử cuộc gọi trong ngày tập trung chủ yếu ở mức 70 cho đến 140.
# - Thời gian sử dụng cuộc gọi trong ngày tập trung chủ yếu ở mức 50 cho đến 280.
# - Thuộc tính 'Total day calls' đạt giá trị cao nhất với hơn 160 cuộc gọi.
# - Thuộc tính 'Total day minutes' đạt giá trị cao nhất với hơn 300 phút gọi.
# - Qua đó cho thấy mức độ sử dụng cuộc gọi trong ngày chiếm  tỉ lệ khá cao ở các khách hàng.

# %%
DrawJointPlot(dataNChurn, 'Total night minutes', 'Total night calls')

# %% [markdown]
# ## Access:
# - Khách hàng sử cuộc gọi trong đêm tập trung chủ yếu ở mức 70 cho đến 130.
# - Thời gian sử dụng cuộc gọi trong ngày tập trung chủ yếu ở mức 50 cho đến 300.
# - Thuộc tính 'Total night calls' đạt giá trị cao nhất với hơn 170 cuộc gọi.
# - Thuộc tính 'Total night minutes' đạt giá trị cao nhất với gần 400 phút gọi.
# - Qua đó cho thấy mức độ sử dụng cuộc gọi trong đêm chiếm  tỉ lệ rất cao ở các khách hàng.

# %%
DrawJointPlot(dataNChurn, 'Total eve minutes', 'Total eve calls')

# %% [markdown]
# ## Access:
# - Khách hàng sử cuộc gọi trong buổi chiều tập trung chủ yếu ở mức 50 cho đến 130 cuộc gọi.
# - Thời gian sử dụng cuộc gọi trong buổi chiều tập trung chủ yếu ở mức 100 cho đến 300 phút.
# - Thuộc tính 'Total eve calls' đạt giá trị cao nhất với gần 175 cuộc gọi.
# - Thuộc tính 'Total eve minutes' đạt giá trị cao nhất với gần 350 phút gọi.
# - Qua đó cho thấy mức độ sử dụng cuộc gọi trong buổi chiều chiếm  tỉ lệ rất cao ở các khách hàng.

# %%
DrawJointPlot(dataNChurn, 'Total intl minutes', 'Total intl calls')

# %% [markdown]
# ## Access:
# - Khách hàng sử cuộc gọi quốc tế tập trung chủ yếu ở mức 2 cho đến 13.
# - Thời gian sử dụng cuộc gọi trong ngày tập trung chủ yếu ở mức 2.5 cho đến 17 phút.
# - Thuộc tính 'Total intl calls' đạt giá trị cao nhất với hơn 17.5 cuộc gọi.
# - Thuộc tính 'Total intl minutes' đạt giá trị cao nhất với hơn 17.5 phút gọi.
# - Qua đó cho thấy mức độ sử dụng cuộc gọi quốc chiếm  tỉ lệ rất thấp ở các khách hàng.

# %%
DrawJointPlot(dataNChurn, 'Total day charge', 'Total night charge')

# %% [markdown]
# ## Access:
#
# - Mức phí mà khách hàng phải trả cho cuộc gọi trong đêm tập trung chủ yếu ở mức 5 cho đến 13.
# - Mức phí mà khách hàng phải trả cho cuộc gọi trong ngày tập trung chủ yếu ở mức 15 cho đến 45.
# - Thuộc tính 'Total night charge' đạt giá trị cao nhất với hơn 17.5.
# - Thuộc tính 'Total day charge' đạt giá trị cao nhất với hơn 50.
# - Qua đó cho thấy phí cuộc gọi trong ngày phải trả cao hơn so với phí cuộc gọi trong đêm phải trả.

# %%
DrawJointPlot(dataNChurn, 'Total eve charge', 'Total intl charge')

# %% [markdown]
# ## Access:
#
# - Mức phí mà khách hàng phải trả cho cuộc gọi quốc tế tập trung chủ yếu ở mức 1 cho đến 4.
# - Mức phí mà khách hàng phải trả cho cuộc gọi trong buổi chiều tập trung chủ yếu ở mức 10 cho đến 25.
# - Thuộc tính 'Total intl charge' đạt giá trị cao nhất với hơn 5.
# - Thuộc tính 'Total eve charge' đạt giá trị cao nhất với hơn 30.
# - Qua đó cho thấy phí cuộc gọi phải trả trong buổi chiều cao hơn so với phí cuộc gọi quốc tế phải trả.

# %% [markdown]
# # Tách dữ liệu theo thuộc tính Churn là 'True'

# %%
dataChurn = data[data['Churn'] == True]
dataChurn.head()
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 10    IN              65        415                 No              No
# 15    NY             161        415                 No              No
# 21    CO              77        408                 No              No
# 33    AZ              12        408                 No              No
# 41    MD             135        408                Yes             Yes
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 10                      0              129.1              137
# 15                      0              332.9               67
# 21                      0               62.4               89
# 33                      0              249.6              118
# 41                     41              173.1               85
#
#     Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 10             21.95              228.5               83             19.42
# ...

# %%
DrawJointPlot(dataChurn, 'Total day minutes', 'Total day calls')

# %% [markdown]
# ## Access:
# - Khách hàng sử cuộc gọi trong ngày tập trung chủ yếu ở mức 70 cho đến 140.
# - Thời gian sử dụng cuộc gọi trong ngày tập trung chủ yếu ở mức 50 cho đến 300.
# - Thuộc tính 'Total day calls' đạt giá trị cao nhất với hơn 160 cuộc gọi.
# - Thuộc tính 'Total day minutes' đạt giá trị cao nhất với hơn 350 phút gọi.
# - Qua đó cho thấy mức độ sử dụng cuộc gọi trong ngày chiếm  tỉ lệ khá cao ở các khách hàng.

# %%
DrawJointPlot(dataChurn, 'Total night minutes', 'Total night calls')

# %% [markdown]
# ## Access:
# - Khách hàng sử cuộc gọi trong đêm tập trung chủ yếu ở dưới mức 60 cho đến 130.
# - Thời gian sử dụng cuộc gọi trong ngày tập trung chủ yếu ở mức 100 cho đến 300.
# - Thuộc tính 'Total night calls' đạt giá trị cao nhất với hơn 170 cuộc gọi.
# - Thuộc tính 'Total night minutes' đạt giá trị cao nhất với gần 400 phút gọi.
# - Qua đó cho thấy mức độ sử dụng cuộc gọi trong đêm chiếm  tỉ lệ rất cao ở các khách hàng.

# %%
DrawJointPlot(dataChurn, 'Total eve minutes', 'Total eve calls')

# %% [markdown]
# ## Access:
# - Khách hàng sử cuộc gọi trong buổi chiều tập trung chủ yếu ở mức 70 cho đến 130 cuộc gọi.
# - Thời gian sử dụng cuộc gọi trong buổi chiều tập trung chủ yếu ở mức 100 cho đến 300 phút.
# - Thuộc tính 'Total eve calls' đạt giá trị cao nhất với gần 175 cuộc gọi.
# - Thuộc tính 'Total eve minutes' đạt giá trị cao nhất với gần 350 phút gọi.
# - Qua đó cho thấy mức độ sử dụng cuộc gọi trong buổi chiều chiếm  tỉ lệ rất cao ở các khách hàng.

# %%
DrawJointPlot(dataChurn, 'Total intl minutes', 'Total intl calls')

# %% [markdown]
# ## Access:
# - Khách hàng sử cuộc gọi quốc tế tập trung chủ yếu ở mức 2 cho đến 10.
# - Thời gian sử dụng cuộc gọi trong ngày tập trung chủ yếu ở mức 4.5 cho đến 17 phút.
# - Thuộc tính 'Total intl calls' đạt giá trị cao nhất với hơn 20 cuộc gọi.
# - Thuộc tính 'Total intl minutes' đạt giá trị cao nhất với hơn 20 phút gọi.
# - Qua đó cho thấy mức độ sử dụng cuộc gọi quốc chiếm  tỉ lệ rất thấp ở các khách hàng.

# %%
DrawJointPlot(dataNChurn, 'Total day charge', 'Total night charge')

# %% [markdown]
# ## Access:
#
# - Mức phí mà khách hàng phải trả cho cuộc gọi trong đêm tập trung chủ yếu ở mức 4 cho đến 13.
# - Mức phí mà khách hàng phải trả cho cuộc gọi trong ngày tập trung chủ yếu ở mức 10 cho đến 49.
# - Thuộc tính 'Total night charge' đạt giá trị cao nhất với hơn 17.5.
# - Thuộc tính 'Total day charge' đạt giá trị cao nhất với hơn 50.
# - Qua đó cho thấy phí cuộc gọi trong ngày phải trả cao hơn so với phí cuộc gọi trong đêm phải trả.

# %%
DrawJointPlot(dataNChurn, 'Total eve charge', 'Total intl charge')

# %% [markdown]
# ## Access:
#
# - Mức phí mà khách hàng phải trả cho cuộc gọi quốc tế tập trung chủ yếu ở mức 1 cho đến 4.
# - Mức phí mà khách hàng phải trả cho cuộc gọi trong buổi chiều tập trung chủ yếu ở mức 5 cho đến 25.
# - Thuộc tính 'Total intl charge' đạt giá trị cao nhất với hơn 5.
# - Thuộc tính 'Total eve charge' đạt giá trị cao nhất với hơn 30.
# - Qua đó cho thấy phí cuộc gọi phải trả trong buổi chiều cao hơn so với phí cuộc gọi quốc tế phải trả.
